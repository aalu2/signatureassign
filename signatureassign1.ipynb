# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def f(x):
    return np.exp(x) - (4 - x**2)

def f_prime(x):
    return np.exp(x) + 2*x

import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def f(x):
    return np.exp(x) - (4 - x**2)

def f_prime(x):
    return np.exp(x) + 2*x

import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def f(x):
    return np.exp(x) - (4 - x**2)

def f_prime(x):
    return np.exp(x) + 2*x

# Initial approximation
x_approx = -1

# Perform Newton's method iterations
for _ in range(100):  # Increase the number of iterations
    x_approx = x_approx - f(x_approx) / f_prime(x_approx)

# Generate data for plotting
x_values = np.linspace(-3, 3, 400)
y1 = np.exp(x_values)
y2 = 4 - x_values**2

# Create the plot
plt.plot(x_values, y1, label='e^x')
plt.plot(x_values, y2, label='4 - x^2')
plt.scatter(x_approx, np.exp(x_approx), color='red', label='Approximation')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Approximation of Negative Root: e^x = 4 - x^2')
plt.legend()
plt.grid(True)

# Display the plot
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(x=x_approx, color='green', linestyle='--', label='Approximation Root')
plt.legend()

plt.show()
